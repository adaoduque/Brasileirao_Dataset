# %%
import numpy as np
import pandas as pd

# %%
d = {'Clubes': [], 'PG': [], 'j': [], 'V': [], 'E': [], 'D': [], 'GP': [], 'GC': [], 'SG': []}
dfClassChampionship = pd.DataFrame(data=d);

# %%
dfDataChampionship = pd.read_excel("b2000.xls")

# %%
dfDataChampionship.head()
# Out:
#   Horario      Dia        Data     Clube 1     Clube 2 Placar    Vencedor  \
# 0   16h00   Sábado  29/07/2000       Vasco       Sport    0x2       Sport
# 1   16h00   Sábado  29/07/2000     Vitória   Palmeiras    4x1     Vitória
# 2   16h00   Sábado  29/07/2000  Fluminense       Bahia    2x0  Fluminense
# 3   16h00  Domingo  30/07/2000  América-MG        Gama    0x1        Gama
# 4   16h00  Domingo  30/07/2000     Guarani  Santa Cruz    0x0           -
#
#       Rodada           Arena
# 0  1ª Rodada    São Januário
# 1  1ª Rodada        Barradão
# 2  1ª Rodada        Maracanã
# 3  1ª Rodada   Independência
# 4  1ª Rodada  Brinco de Ouro

# %% [markdown]
# ** Get all clubes for championship **

# %%
#Cancatenando as colunas Clube 1 e Clube 2
clubs  =  pd.concat([dfDataChampionship['Clube 1'].str.lower(), dfDataChampionship['Clube 2'].str.lower()], axis=1, keys=['Clubes'])

# %%
#Obtem todos os clubes 
cb = pd.DataFrame({'Clubes': clubs['Clubes'].unique()})

# %%
#Todos os clubes que participaram dp campeonato
#cb

# %%
def getNumberWinner(data, clube ):
    filter = data["Vencedor"].str.lower() == clube
    return (data[filter]['Vencedor'].count()).astype(np.int64)

def getNumberDepartures(data, clube ):
    filter1 = data["Clube 1"].str.lower() == clube
    filter2 = data["Clube 2"].str.lower() == clube
    return (data[filter1]['Clube 1'].count() + data[filter2]['Clube 2'].count()).astype(np.int64)

def getPoints(data, clube ):
    filter1 = data["Clube 1"].str.lower() == clube
    filter2 = data["Clube 2"].str.lower() == clube
    filter3 = data["Vencedor"].str.lower() == clube
    filter4 = (data["Clube 1"].str.lower() == clube) | (data["Clube 2"].str.lower() == clube)
    filter5 = data["Vencedor"].str.lower() == '-'
    
    v1 = data[(filter1) & (filter3)]
    v1 = v1['Vencedor'].count()
    v2 = data[(filter2) & (filter3)]
    v2 = v2['Vencedor'].count() 
    v3 = data[(filter4) & (filter5)]
    v3 = v3['Vencedor'].count()    
    return ((v2*3)+(v1*3)+v3).astype(np.int64)

def getDraw(data, clube ):
    filter1 = (data["Clube 1"].str.lower() == clube) | (data["Clube 2"].str.lower() == clube)
    filter2 = data["Vencedor"].str.lower() == '-'
    df = data[(filter1) & (filter2)]
    empates = df['Vencedor'].count()
    return empates.astype(np.int64)

def getDefeats(data, clube ):
    filter1 = (data["Clube 1"].str.lower() == clube) | (data["Clube 2"].str.lower() == clube)
    filter2 = (data["Vencedor"].str.lower() != clube) & (data["Vencedor"].str.lower() != '-')
    df = data[(filter1) & (filter2)]
    derrotas = df['Vencedor'].count()
    return derrotas.astype(np.int64)

def getGP(data, clube ):
    filter1  =  data["Clube 1"].str.lower() == clube
    filter2  =  data["Clube 2"].str.lower() == clube
    df1      =  data[(filter1)]
    df2      =  data[(filter2)]
    placar1  =  df1['Placar'].str.split('x')
    placar2  =  df2['Placar'].str.split('x')
    gp       =  0
    gc       =  0
    for g1, g2 in placar1:
        gp = (gp + pd.to_numeric( g1 ))
        gc = (gc + pd.to_numeric( g2 ))
            
    for g1, g2 in placar2:
        gp = (gp + pd.to_numeric( g2 )) 
        gc = (gc + pd.to_numeric( g1 ))
    return gp, gc

# %%
dfTable = cb[["Clubes"]].copy()

for column in ["PG", "J", "V", "E", "D", "GP", "GC", "SG"]:
    dfTable[column] = pd.np.nan
    
for index, row in dfTable.iterrows():
    gp, gc   =  getGP(dfDataChampionship, row["Clubes"] )
    
    dfTable.at[index, 'PG'] = getPoints(dfDataChampionship, row["Clubes"] )
    dfTable.at[index, 'J']  = getNumberDepartures(dfDataChampionship, row["Clubes"] )
    dfTable.at[index, 'V']  = getNumberWinner(dfDataChampionship, row["Clubes"] )    
    dfTable.at[index, 'E']  = getDraw(dfDataChampionship, row["Clubes"] )
    dfTable.at[index, 'D']  = getDefeats(dfDataChampionship, row["Clubes"] )
    dfTable.at[index, 'GP'] = gp
    dfTable.at[index, 'GC'] = gc
    dfTable.at[index, 'SG'] = gp - gc

# %%
reorderlist = ['vasco'   , 'são caetano', 'cruzeiro'   , 'grêmio'     , 'sport'    , 'internacional', 'palmeiras' , 
               'paraná'  , 'fluminense' , 'goiás'      , 'ponte preta', 'são paulo', 'atlético-pr'  , 'bahia'     , 
               'malutrom', 'remo'       , 'guarani'    , 'santos'     , 'flamengo' , 'botafogo'     , 'portuguesa', 
               'vitória' , 'américa'    , 'atlético-mg', 'juventude'  , 'gama'     , 'coritiba'     ,'corinthians',
               'santa cruz']
listIndex   = []

#Processa a lista para gerar a lista de ordenação
for clube in reorderlist:
    for index, row in dfTable.iterrows():
        #Verifica se o valor de clube é um unicode, se não, convete isso.
        if type(clube) != unicode:
            c =  clube.decode('utf-8')
        else:
            c =  clube
        
        #Verifica se o clube iterado é igual ao clube da lista, se sim
        #retorna seu indice
        if row['Clubes'] == c:
            listIndex.append( index )
            break

#Reordena a lista
dfTable       =  dfTable.reindex(index=listIndex, columns=["Clubes", "PG", "J", "V", "E", "D", "GP", "GC", "SG"])

#Com a lista ordenada, corrige os indices.
dfTable.index =  np.arange(1, len(dfTable)+1)
dfTable
# Out:
#            Clubes    PG     J     V     E     D    GP    GC    SG
# 1           vasco  54.0  32.0  15.0   9.0   8.0  54.0  49.0   5.0
# 2     são caetano  15.0   8.0   4.0   3.0   1.0  18.0  15.0   3.0
# 3        cruzeiro  54.0  30.0  14.0  12.0   4.0  57.0  36.0  21.0
# 4          grêmio  44.0  30.0  12.0   8.0  10.0  45.0  41.0   4.0
# 5           sport  49.0  28.0  14.0   7.0   7.0  51.0  31.0  20.0
# 6   internacional  43.0  28.0  11.0  10.0   7.0  39.0  30.0   9.0
# 7       palmeiras  42.0  28.0  11.0   9.0   8.0  37.0  38.0  -1.0
# 8          paraná   7.0   4.0   2.0   1.0   1.0   6.0   4.0   2.0
# 9      fluminense  43.0  26.0  12.0   7.0   7.0  48.0  35.0  13.0
# 10          goiás  42.0  26.0  11.0   9.0   6.0  42.0  33.0   9.0
# 11    ponte preta  41.0  26.0  12.0   5.0   9.0  51.0  39.0  12.0
# 12      são paulo  40.0  26.0  10.0  10.0   6.0  48.0  38.0  10.0
# 13    atlético-pr  39.0  26.0  11.0   6.0   9.0  33.0  30.0   3.0
# 14          bahia  37.0  26.0  10.0   7.0   9.0  37.0  37.0   0.0
# 15       malutrom   1.0   2.0   0.0   1.0   1.0   1.0   4.0  -3.0
# 16           remo   0.0   2.0   0.0   0.0   2.0   1.0   3.0  -2.0
# 17        guarani  35.0  24.0   9.0   8.0   7.0  29.0  29.0   0.0
# 18         santos  33.0  24.0   9.0   6.0   9.0  38.0  31.0   7.0
# 19       flamengo  33.0  24.0   9.0   6.0   9.0  42.0  37.0   5.0
# 20       botafogo  32.0  24.0   9.0   5.0  10.0  31.0  35.0  -4.0
# 21     portuguesa  32.0  24.0   9.0   5.0  10.0  34.0  43.0  -9.0
# 22        vitória  31.0  24.0   9.0   4.0  11.0  44.0  40.0   4.0
# 23    atlético-mg  27.0  24.0   7.0   6.0  11.0  31.0  42.0 -11.0
# 24      juventude  26.0  24.0   7.0   5.0  12.0  27.0  36.0  -9.0
# 25           gama  22.0  24.0   6.0   4.0  14.0  22.0  39.0 -17.0
# 26       coritiba  21.0  24.0   5.0   6.0  13.0  26.0  35.0  -9.0
# 27    corinthians  16.0  24.0   4.0   4.0  16.0  26.0  46.0 -20.0
# 28     santa cruz  16.0  24.0   3.0   7.0  14.0  18.0  51.0 -33.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def GPxGC(data, clube ):
    if type(clube) != unicode:
        clube =  clube.decode('utf-8')
    filter1  =  data["Clube 1"].str.lower() == clube
    filter2  =  data["Clube 2"].str.lower() == clube
    df1      =  data[(filter1)]
    df2      =  data[(filter2)]
    placar1  =  df1['Placar'].str.split('x')
    placar2  =  df2['Placar'].str.split('x')
    gp       =  []
    gc       =  []
    for g1, g2 in placar1:
        gp.append(pd.to_numeric( g1 ))
        gc.append(pd.to_numeric( g2 ))
            
    for g1, g2 in placar2:
        gp.append(pd.to_numeric( g2 ))
        gc.append(pd.to_numeric( g1 ))
    return gp, gc

# %%
#Gols PRO vs Gols Contra
data  =  dfDataChampionship

gp, gc = GPxGC(data, 'vitória' )

fig = plt.figure(figsize=(20, 8))
plt.plot(gp, 'b--')
plt.plot(gc, 'r*-')
plt.xlabel('Quantidade de Gols')
plt.ylabel('Gols')
plt.title('Gols PRO vs Gols Contra')
plt.legend(['Gols Pro', 'Gols Contra'])

# %%
import seaborn as sns

# %%
#Curva KDE
gp, gc = GPxGC(data, 'vasco' )
sns.distplot(gp)

# %%
gp, gc = GPxGC(data, 'vasco' )
d = {'gp': gp, 'gc': gc}
df = pd.DataFrame(data=d)

#Mapa de calor na maior quantidade de dados
sns.jointplot(x='gp', y='gc', data=df, kind='hex')

# %%
#Join nos plots
sns.pairplot(data=df, palette='coolwarm')

# %%
#verificando onde está a maioria dos dados
sns.rugplot(df['gc'])
